# %% [markdown]
# <a href="https://colab.research.google.com/github/MURUGA-21/DS-MINOR-APRIL/blob/main/DS_MINOR_APRIL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ipython-autotime
# %load_ext autotime
# Out:
# ...
# time: 216 µs (started: 2021-05-24 11:48:30 +00:00)

# %%
 # Data : Images
 # 1. Download manually the images from Google
 # 2. Download dataset from Kaggle.com
 # 3. Build a Image Web Crawler
 # 4. Use Python libraries to scrape the images (using)

# %%
 # !pip install bing-image-downloader

# %%
# !mkdir images

# %%
from bing_image_downloader import downloader
downloader.download("pretty tulipflower",limit=30,output_dir='images',
                    adult_filter_off=True)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 10 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://www.statelykitsch.com/wp-content/uploads/2013/03/tulip1-1024x1024.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.pinimg.com/736x/f0/13/df/f013dfb557651312e301c4ea0efaf42d--english-gardens-perennial.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://i.pinimg.com/originals/c1/7a/e4/c17ae4c06f07e6920be5e2a02bc25d2b.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://i.pinimg.com/736x/35/07/23/3507238da6824173b39f7e060e585624--dutch-tulip-tulips-flowers.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://www.waterwiseplants.org/images/plants/Tulipa 'Little Beauty' (1).jpg?width=487&amp;height=487&amp;mode=crop&amp;bgcolor=fff
# [!] Issue getting: https://www.waterwiseplants.org/images/plants/Tulipa 'Little Beauty' (1).jpg?width=487&amp;height=487&amp;mode=crop&amp;bgcolor=fff
# ...

# %%
downloader.download("mountains",limit=30,output_dir='images',
                    adult_filter_off=True)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 10 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.hdwallpapers.in/download/river_between_green_trees_forest_and_tree_covered_rocks_in_a_background_of_colorful_mountains_under_cloudy_snow_and_sky_4k_hd_nature-1920x1080.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://wallpapershome.com/images/wallpapers/mountain-1440x2560-lake-trees-4k-16728.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.hdwallpapers.in/download/mountains_under_black_cloudy_sky_in_yosemite_forest_4k_hd_nature-1920x1080.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://wallpapershome.com/images/wallpapers/jordan-3840x2160-petra-rocks-horse-4k-16485.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://iphoneswallpapers.com/wp-content/uploads/2016/12/Jasper-National-Park-Rocky-Mountains-iPhone-Wallpaper-iphoneswallpapers_com.jpg
# [%] File Downloaded !
#
# ...

# %%
downloader.download("waterfalls",limit=30,output_dir='images',
                    adult_filter_off=True)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 10 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.wallpapers13.com/wp-content/uploads/2016/05/Beautiful-Landscape-Wallpaper-HD-resolution-waterfalls-in-Iceland-1280x960.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.chinawhisper.com/wp-content/uploads/2013/01/Mt.-Lushan-waterfall.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://www.wallpapers13.com/wp-content/uploads/2016/09/Havasu-Falls-Havasupai-Arizona-U.S-Desktop-HD-Wallpaper-1920x1080-1024x768.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://cdn.architecturendesign.net/wp-content/uploads/2015/07/AD-Fairy-Tale-Viking-Architecture-Norway-05.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://www.worthminer.com/wp-content/uploads/2017/07/Beautiful-places-in-Australia-9.jpg
# [%] File Downloaded !
#
# ...
